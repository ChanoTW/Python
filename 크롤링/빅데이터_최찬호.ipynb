# %% [markdown]
# # Question2

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time

# %%
driver = wb.Chrome()
driver.get("http://www.naver.com")
search = driver.find_element_by_id("query")
search.send_keys("크롤링")
search.send_keys(Keys.ENTER)
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10232/1960449504.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_id("query")

# %% [markdown]
# # Question3

# %%
import pandas as pd

# %%
driver = wb.Chrome()
time.sleep(0.5)
driver.get("http://corners.gmarket.co.kr/Bestsellers")
time.sleep(0.5)
titleList = []
priceList = []
for i in range(10) :
    img = driver.find_elements_by_css_selector("img.lazy")
    img[i].click()
    time.sleep(1)
    title = driver.find_element_by_css_selector(".itemtit")
    price = driver.find_element_by_css_selector(".price_real")
    # 순수한 글자정보만 저장해주는 리스트 작업
    titleList.append(title.text)
    priceList.append(price.text)
    driver.back()
    time.sleep(1)
dic = {"상품명" : titleList, "가격" : priceList}
gmarket = pd.DataFrame(dic)
gmarket
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10232/1739248352.py:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   img = driver.find_elements_by_css_selector("img.lazy")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10232/1739248352.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title = driver.find_element_by_css_selector(".itemtit")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10232/1739248352.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price = driver.find_element_by_css_selector(".price_real")
#                                                  상품명        가격
# 0                                       후디스 초유단백질 2개   30,000원
# 1                                    버팔로치킨윙봉 1kg+1kg   24,900원
# 2                       한양식품 꽃보다오징어 오리지날 260g+260g 외   33,230원
# 3                       설빅20%/윈터스웨트셔츠10종/가을/스웨트셔츠20종   10,000원
# 4                  청도 반건시곶감 10입+10입+10입 (3팩/개당40g내외)   17,900원
# 5                       참닭 춘천형 닭갈비 700g x 4팩 총 2.8kg   19,900원
# 6                   (7팩 10940)베스트셀러 생리대/3세트 구매시 4팩증정   17,800원
# 7                   산지애 사과원액주스 60팩 / 사과즙 100% 착즙 NFC   38,130원
# 8       수퍼맘스토리카페/예술적 사고력을 키워주는/디자인키즈 명화미술/영어미술/2주내배송  113,800원
# 9  (신세계경기점) MENS RUNNING 런팔콘 2.0 (FY5943 GX8238 G...   39,210원

# %% [markdown]
# # Question4

# %% [markdown]
# # 문제1

# %%
import requests as req
from bs4 import BeautifulSoup as bs

# %%
url = 'https://www.melon.com/chart/index.htm'
h = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36'}
res = req.get(url, headers = h)
soup = bs(res.text)
title = soup.select('div.ellipsis.rank01 > span > a')
singer = soup.select('div.ellipsis.rank02 > a:nth-child(1)')
title_list = []
singer_list = []
rank_list = []

for i in range(len(title)):
    title_list.append(title[i].text)
    singer_list.append(singer[i].text)
    rank_list.append(i+1)

dic = {'노래제목':title_list, '가수' : singer_list, '순위':rank_list}
df = pd.DataFrame(dic)
df.set_index('순위', inplace = True)
df.to_csv("멜론차트.csv", encoding="euc-kr")
df
# Out:
#                                        노래제목             가수
# 순위
# 1                                      취중고백     김민석 (멜로망스)
# 2                                 사랑은 늘 도망가            임영웅
# 3    회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)       sokodomo
# 4           Counting Stars (Feat. Beenzino)      BE'O (비오)
# 5             리무진 (Feat. MINO) (Prod. GRAY)      BE'O (비오)
# ..                                      ...            ...
# 96   깐부 (Feat. 염따, ASH ISLAND) (Prod. TOIL)             쿤타
# 97   Peaches (Feat. Daniel Caesar & Giveon)  Justin Bieber
# 98                                밤새 서로 미루다             존박
# 99                            Santa Tell Me  Ariana Grande
# 100                                 아직도 좋아해            양요섭
#
# [100 rows x 2 columns]

# %% [markdown]
# # 문제2

# %%
driver = wb.Chrome()
driver.get('https://www.hsd.co.kr/menu/menu_list')
title = driver.find_elements_by_css_selector('h4.h.fz_03')
price = driver.find_elements_by_css_selector('.item-price>strong')
btn = driver.find_element_by_css_selector("a.c_05")

try :
    for i in range(10) :
        btn.click()
        time.sleep(2)
except :
    print("더보기가 끝났습니다.")

title = driver.find_elements_by_css_selector("h4.h.fz_03")
price = driver.find_elements_by_css_selector("div.item-price > strong")

titleList = []
priceList = []
for i in range(len(title)) :
    titleList.append(title[i].text)
    priceList.append(price[i].text)

data = {"메뉴명" : titleList, "가격" : priceList}
food = pd.DataFrame(data)
food.to_csv("한솥.csv", encoding="euc-kr")
food
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10232/2772690268.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title = driver.find_elements_by_css_selector('h4.h.fz_03')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10232/2772690268.py:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   price = driver.find_elements_by_css_selector('.item-price>strong')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10232/2772690268.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   btn = driver.find_element_by_css_selector("a.c_05")
# 더보기가 끝났습니다.
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10232/2772690268.py:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title = driver.find_elements_by_css_selector("h4.h.fz_03")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10232/2772690268.py:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   price = driver.find_elements_by_css_selector("div.item-price > strong")
#                      메뉴명     가격
# 0           행사 숯불직화구이 덮밥  4,900
# 1       행사 제육 김치 부대찌개 정식  7,200
# 2    행사 빅치킨마요 김치 부대찌개 정식  6,300
# 3         행사 돈까스도련님 고기고기  4,900
# 4                  행사 동백  4,600
# ..                   ...    ...
# 106              무말랭이 무침    300
# 107                  한솥밥  1,000
# 108                  현미밥  1,700
# 109           리얼 티라미수 찰떡  1,500
# 110             아이스 애플망고  1,500
#
# [111 rows x 2 columns]
